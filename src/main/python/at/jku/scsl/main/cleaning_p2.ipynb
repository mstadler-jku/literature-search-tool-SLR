# %%
import os.path
import pandas as pd

# paths
KW_CSV_PATH = os.path.join('outputs','cleaning_export', 'raw_literature_parser_result.csv')

# read data
df_kw_search = pd.read_csv(KW_CSV_PATH)

# print length
print(f'Length of dataset: \t{len(df_kw_search)}')
# Out:
# Length of dataset: 	4423

# %%
df_kw_search
# Out:
#         id                                              title                                            authors                       doi                                               link pub_year              type                                           abstract          source                                          pub_title
# 0        0  An integrated state transition-Boolean logic m...                 A. Zimba; C. Hongsong; W. Zhaoshun  10.1109/CCI.2016.7778962  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...   2016.0  IEEE Conferences  The hype over cloud computing cannot go unnoti...     IEEE Xplore  2016 First IEEE International Conference on Co...
# ...

# %%
df_kw_search['type'].value_counts()
# Out:
# type
# Conference paper                               1395
# Article                                        1112
# IEEE Conferences                               1045
# Conference Paper                                344
# IEEE Journals                                   209
# Journal Article                                  92
# Book chapter                                     64
# Review                                           39
# IEEE Magazines                                   22
# Book                                             17
# IET Conferences                                  16
# IEEE Early Access Articles                       14
# River eBook Chapters                             13
# IEEE Standards                                    7
# Wiley Data and Cybersecurity eBook Chapters       5
# SGEPRI Journals                                   4
# TUP Journals                                      3
# OUP Journals                                      3
# ...

# %%
# remove unwanted types
df_kw_search['type'].value_counts()
unwanted_types = ['Standards', 'Editorial', 'Short survey', 'IEEE Standards', 'Review', 'Erratum',
                  'Note', 'Data paper']
df_kw_search = df_kw_search[df_kw_search.type.isin(unwanted_types) == False]
print(len(df_kw_search))
df_kw_search
# Out:
# 4370
#         id                                              title                                            authors                       doi                                               link pub_year              type                                           abstract          source                                          pub_title
# 0        0  An integrated state transition-Boolean logic m...                 A. Zimba; C. Hongsong; W. Zhaoshun  10.1109/CCI.2016.7778962  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...   2016.0  IEEE Conferences  The hype over cloud computing cannot go unnoti...     IEEE Xplore  2016 First IEEE International Conference on Co...
# ...

# %%
df_kw_search['type'].value_counts()
# Out:
# type
# Conference paper                               1395
# Article                                        1112
# IEEE Conferences                               1045
# Conference Paper                                344
# IEEE Journals                                   209
# Journal Article                                  92
# Book chapter                                     64
# IEEE Magazines                                   22
# Book                                             17
# IET Conferences                                  16
# IEEE Early Access Articles                       14
# River eBook Chapters                             13
# Wiley Data and Cybersecurity eBook Chapters       5
# SGEPRI Journals                                   4
# OUP Journals                                      3
# TUP Journals                                      3
# VDE Conferences                                   3
# Chapter ConferencePaper                           2
# ...

# %%
df_kw_search[df_kw_search.doi.isna()][df_kw_search.link.isna()]
# Out:
# C:\Users\mstad\AppData\Local\Temp\ipykernel_18184\3114496103.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_kw_search[df_kw_search.doi.isna()][df_kw_search.link.isna()]
#         id                                              title                                            authors  doi link pub_year              type                                           abstract               source                                          pub_title
# 3820     2  Trustworthy Multi-Modal Framework for Life-Cri...           Rao A,Rozenblit J,Lysecky R,Sametinger J  NaN  NaN     2018  Conference Paper  With the advent of network connectivity and co...  ACM Digital Library     Proceedings of the Annual Simulation Symposium
# ...

# %%
df_kw_search[df_kw_search.authors.isna()]
# Out:
#         id                                              title authors                           doi                                               link    pub_year                     type                                           abstract               source                                          pub_title
# 463    476  2012 4th InternationalWorkshop on Hot Topics i...     NaN  10.1109/HotSWUp.2012.6226606  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...      2012.0         IEEE Conferences  The following topics are dealt with: just-in-t...          IEEE Xplore  2012 4th International Workshop on Hot Topics ...
# 1298  1369                                  Table of contents     NaN       10.1109/SER-IP.2017..16  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...      2017.0         IEEE Conferences  The following topics are dealt with: software ...          IEEE Xplore  2017 IEEE/ACM 4th International Workshop on So...
# ...

# %%
# remove entries that are no actual papers
dois_to_remove = ['10.1109/HotSWUp.2012.6226606', '10.1109/SER-IP.2017..16', '10.1109/ICHB.2011.6094345',
                  '10.1109/MMIT.2010.1', '10.1109/AVSS.2010.3']
titles_to_remove = [
    "SIN '13: Proceedings of the 6th International Conference on Security of Information and Networks",
    "ANC '13: Proceedings of the Second ACM MobiHoc Workshop on Airborne Networks and Communications",
    "Airborne '12: Proceedings of the First ACM MobiHoc Workshop on Airborne Networks and Communications",
    "7th International Conference on Applied Computing and Information Technology, ACIT 2019",
    "IEEE Draft Standard for Biometric Multi-modal Fusion"]
df_kw_search = df_kw_search[df_kw_search.doi.isin(dois_to_remove) == False]
df_kw_search = df_kw_search[df_kw_search.title.isin(titles_to_remove) == False]

# construct proper index column
df_kw_search = df_kw_search.reset_index()
df_kw_search.id = df_kw_search.index + 1
df_kw_search = df_kw_search.drop('index', axis=1)
df_kw_search
# Out:
#         id                                              title                                            authors                       doi                                               link pub_year              type                                           abstract          source                                          pub_title
# 0        1  An integrated state transition-Boolean logic m...                 A. Zimba; C. Hongsong; W. Zhaoshun  10.1109/CCI.2016.7778962  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...   2016.0  IEEE Conferences  The hype over cloud computing cannot go unnoti...     IEEE Xplore  2016 First IEEE International Conference on Co...
# ...

# %% [markdown]
# ## Export

# %%
df_kw_search.to_csv((os.path.join('outputs', 'cleaning_export', 'cleaning_p2.csv')), sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ## Get random entries for checking clear irrelevant exclusion

# %%
rand_ids = pd.read_csv(os.path.join('rnd_id', '01_rand.txt'), header=None)
rand_ids = rand_ids.set_axis(['ids'], axis=1)
df_rand_first = df_kw_search[df_kw_search.id.isin(rand_ids.ids)]
df_rand_first.to_csv(os.path.join('outputs', '01_clear_irrelevant', 'first_rnd.csv'), sep=',')
df_rand_first
# Out:
#         id                                              title                                          authors                        doi                                               link pub_year              type                                           abstract          source                                          pub_title
# 57      58  Static Vulnerabilities Detection Based on Exte...                                         B. Liang     10.1109/NSWCTC.2009.10  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...   2009.0  IEEE Conferences  A static vulnerability detection method based ...     IEEE Xplore  2009 International Conference on Networks Secu...
# ...

# %%
rand_ids = pd.read_csv(os.path.join('rnd_id', '02_rand.txt'), header=None)
rand_ids = rand_ids.set_axis(['ids'], axis=1)
df_rand_sec = df_kw_search[df_kw_search.id.isin(rand_ids.ids)]
df_rand_sec.to_csv(os.path.join('outputs', '01_clear_irrelevant', 'sec_rnd.csv'), sep=',')
df_rand_sec
# Out:
#         id                                              title                                            authors                                    doi                                               link pub_year              type                                           abstract          source                                          pub_title
# 17      18  Semantic Intrusion Detection System using patt...              K. S. Ganesh; M. R. Sekar; V. Vaidehi            10.1109/ICRTIT.2011.5972244  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...   2011.0  IEEE Conferences  Emerging technologies have metamorphosed the n...     IEEE Xplore  2011 International Conference on Recent Trends...
# ...

# %%
rand_ids = pd.read_csv(os.path.join('rnd_id', '03_rand.txt'), header=None)
rand_ids = rand_ids.set_axis(['ids'], axis=1)
df_rand_third = df_kw_search[df_kw_search.id.isin(rand_ids.ids)]
df_rand_third.to_csv(os.path.join('outputs', '01_clear_irrelevant', 'third_rnd.csv'), sep=',')
df_rand_third
# Out:
#         id                                              title                                          authors                              doi                                               link pub_year              type                                           abstract          source                                          pub_title
# 45      46  Frequency Response Capabilities of Utility-sca...                      M. G. Dozein; P. Mancarella  10.1109/ICPES47639.2019.9105646  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...   2019.0  IEEE Conferences  This paper is aimed to investigate the capabil...     IEEE Xplore  2019 9th International Conference on Power and...
# ...
